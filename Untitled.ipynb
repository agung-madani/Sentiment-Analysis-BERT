# %%
import pandas as pd

df = pd.read_csv("dataGabungan_appsLokal.csv")
pd.set_option('display.max_rows', None)
df
# Out:
#                                                 content     Pelabelan  label
# 0                                                Mantap   positif (1)      0
# 1                                  Bagus nyaman berguna   positif (1)      0
# 2                                  Knp gak bisa di buka    netral (0)      2
# 3                                                    Ok   positif (1)      0
# 4                                 tap mantap tul mantul   positif (1)      0
# 5                                    lengkap terpercaya   positif (1)      0
# 6                                        Cukup membantu   positif (1)      0
# 7     MAU PUTUSIN AKUN DANA AJA RIBET BANGET ANJ***....  negatif (-1)      1
# 8     Tetap konsisten.. Tanpa ada jasa layanan dannt...    netral (0)      2
# 9                                           is the best   positif (1)      0
# 10                              Good luck for Bukalapak   positif (1)      0
# ...
